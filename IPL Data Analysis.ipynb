# %% [markdown]
# #                             IPL Data  Analytics using pandas

# %% [markdown]
# ### Dataset  downloaded  from kaggle

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data =pd.read_csv('deliveries.csv')
#read csv file
type(data)
#to determine type of data
# Out:
# pandas.core.frame.DataFrame

# %%
data
# print data
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
data.head()
# to obtain only summary
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
# %matplotlib inline
# plotting within jupyter notebook(optional)
data.head(30).plot(x='ball',y='total_runs')
# from data frame we plot graph from data's top 30 rows such that x-axis= ball and y-axis=total runs

# %%
data[data['over']==1] ['batsman']
# Out:
# 0            DA Warner
# 1            DA Warner
# 2            DA Warner
# 3            DA Warner
# 4            DA Warner
#               ...
# 178955    F du Plessis
# 178956    F du Plessis
# 178957    F du Plessis
# 178958       SR Watson
# 178959       SR Watson
# Name: batsman, Length: 9603, dtype: object

# %%
data[data ['over']==1]
# data frame wherein over coloumn has value 1
# data will be displayed when in data  over field has value 1
# we usually write conditions in square brackets
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 178955     11415       2  Chennai Super Kings               Mumbai Indians
# 178956     11415       2  Chennai Super Kings               Mumbai Indians
# 178957     11415       2  Chennai Super Kings               Mumbai Indians
# 178958     11415       2  Chennai Super Kings               Mumbai Indians
# 178959     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
over = data[data['match_id']==1] ['over']
#we choose data field coloumn OVER of data where match id is  1

# %% [raw]
#  over = data[data['match_id']==1]
# This would mean all fields of data wher match_id=1 would be choosen

# %%
run = data[(data['match_id']==1) & (data['over']==1)]['total_runs'].sum()
# two conditions when match id=1 and over=1 in such case total number of run

# %%
run
# Out:
# 18

# %%
(data['over'].value_counts()/6).plot(kind='bar')
#.value_counts()counts number of overs which are completed

# %%
(data['over'].value_counts()/6).plot(kind='pie')
#kind can pie for pie chart or bar for bar graph

# %%
(data['over'].value_counts()/6).plot(kind='area')

# %%
match=pd.read_csv('matches.csv')

# %%
match.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match['player_of_match'].value_counts()
# arranged in descending order of count of the player_of_match field
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
#                   ..
# BCJ Cutting        1
# S Anirudha         1
# RJ Harris          1
# AD Mathews         1
# LJ Wright          1
# Name: player_of_match, Length: 226, dtype: int64

# %%
# Who won most MAN OF THE MATCH  awards
match['player_of_match'].value_counts().head(15).plot(kind='pie',figsize=(8,8))
# we choose only top 15 for plotting

# %%
match['player_of_match'].value_counts().head(15).plot(kind='bar',figsize=(15,5))
# fig size(width,height)

# %%
match['winner'].value_counts().plot(kind='bar',figsize=(15,5))
#WINNING TEAM of matches

# %%
match['winner'].value_counts().plot(kind='pie')
#WINNING TEAM of matches

# %%
match['winner'].value_counts().head(5).plot(kind='pie',figsize=(5,5))
#WINNING TEAM of matches

# %%
(match['winner'].value_counts()/10).plot(kind='pie',figsize=(15,5))
#WINNING TEAM of matches
